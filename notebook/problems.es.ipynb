# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
# TODO
from scipy.stats import norm, uniform

# Definir todas las funciones de probabilidad relacionadas con la distribución normal.

def dnorm(x, loc=0, scale=1):
    """
    Calcula la densidad de probabilidad de la distribución normal.
    """
    result = norm.pdf(x, loc=loc, scale=scale)
    return result

def pnorm(q, loc=0, scale=1):
    """
    Calcula el acumulado de la distribución normal.
    """
    result = norm.cdf(q, loc=loc, scale=scale)
    return result

def qnorm(p, loc=0, scale=1):
    """
    Calcula la función cuantil a partir de la distribución normal.
    """
    result = norm.ppf(p, loc=loc, scale=scale)
    return result

def rnorm(n, loc=0, scale=1):
    """
    Genera variables aleatorias a partir de la distribución normal.
    """
    result = norm.rvs(loc=loc, scale=scale, size=n)
    return result

# %%
# Distribución normal con media 0 y desviación estándar 1
np.random.seed(42)

print(f"Probability density of Normal(0,1) at x=2: {dnorm(2, loc=0, scale=1)}")
print(f"Probability that a Normal(0,1) takes a value less than 2: {pnorm(2, loc=0, scale=1)}")
print(f"Which value of a Normal(0,1) has a cumulative probability of 0.9? {qnorm(0.9, loc=0, scale=1)}")

# Generar 2000 valores aleatorios de una Normal(0,1)
random_values = rnorm(2000, loc=0, scale=1)
# Out:
# Probability density of Normal(0,1) at x=2: 0.05399096651318806
# Probability that a Normal(0,1) takes a value less than 2: 0.9772498680518208
# Which value of a Normal(0,1) has a cumulative probability of 0.9? 1.2815515655446004

# %%
np.random.seed(42) # SEMILLA PARA REPRODUCIBILIDAD

# Parámetros de la distribución normal
loc = 0    # Media
scale = 1  # Desviación estándar (std)

data = rnorm(2000, loc=loc, scale=scale)

pdf = dnorm(data, loc=loc, scale=scale)  # Calcular Densidad de probabilidad
cdf = pnorm(data, loc=loc, scale=scale)  # Función de distribución acumulada
ppf = qnorm(cdf, loc=loc, scale=scale)   # Cuantil inverso (debería devolver data)

# Crear subgráficos
fig, axis = plt.subplots(3, 1, figsize=(5, 7))

# Graficar PDF (Densidad de probabilidad)
axis[0].plot(data, pdf, "r.", alpha=0.5)
axis[0].set_title("PDF - Densidad de probabilidad")

# Graficar CDF (Función acumulada)
axis[1].plot(np.sort(data), np.sort(cdf), "b-", alpha=0.5)
axis[1].set_title("CDF - Función de distribución acumulada")

# Graficar PPF (Función cuantil)
axis[2].plot(np.sort(cdf), np.sort(ppf), "g-", alpha=0.5)
axis[2].set_title("PPF - Función cuantil inversa")

plt.tight_layout()
plt.show()

# %%
# Definir todas las funciones de probabilidad relacionadas con la distribución uniforme.

def duniform(x, loc=0, scale=1):
    """
    Calcula la densidad de probabilidad de la distribución normal.
    """
    result = uniform.pdf(x, loc=loc, scale=scale)
    return result

def puniform(q, loc=0, scale=1):
    """
    Calcula el acumulado de la distribución normal.
    """
    result = uniform.cdf(q, loc=loc, scale=scale)
    return result

def quniform(p, loc=0, scale=1):
    """
    Calcula la función cuantil a partir de la distribución normal.
    """
    result = uniform.ppf(p, loc=loc, scale=scale)
    return result

def runiform(n, loc=0, scale=1):
    """
    Genera variables aleatorias a partir de la distribución normal.
    """
    result = uniform.rvs(loc=loc, scale=scale, size=n)
    return result

# %%
np.random.seed(42)

print(f"Probability density of Uniform(0,1) at x=2: {duniform(2, loc=0, scale=1)}")
print(f"Probability that a Uniform(0,1) takes a value less than 2: {puniform(2, loc=0, scale=1)}")
print(f"Which value of a Uniform(0,1) has a cumulative probability of 0.9? {quniform(0.9, loc=0, scale=1)}")

# Generar 2000 valores aleatorios de una Uniform(0,1)
random_values = runiform(2000, loc=0, scale=1)

# Mostrar algunos de los valores generados
print(f"First 10 random values from Uniform(0,1): {random_values[:10]}")
# Out:
# Probability density of Uniform(0,1) at x=2: 0.0
# Probability that a Uniform(0,1) takes a value less than 2: 1.0
# Which value of a Uniform(0,1) has a cumulative probability of 0.9? 0.9
# First 10 random values from Uniform(0,1): [0.37454012 0.95071431 0.73199394 0.59865848 0.15601864 0.15599452
#  0.05808361 0.86617615 0.60111501 0.70807258]

# %%
np.random.seed(42) # SEMILLA PARA REPRODUCIBILIDAD

# Parámetros de la distribución normal
loc = 0    # Media
scale = 1  # Desviación estándar (std)

data = runiform(2000, loc=loc, scale=scale)

pdf = duniform(data, loc=loc, scale=scale)  # Calcular Densidad de probabilidad
cdf = puniform(data, loc=loc, scale=scale)  # Función de distribución acumulada
ppf = quniform(cdf, loc=loc, scale=scale)   # Cuantil inverso (debería devolver data)

# Crear subgráficos
fig, axis = plt.subplots(3, 1, figsize=(5, 7))

# Graficar PDF (Densidad de probabilidad)
axis[0].plot(data, pdf, "r.", alpha=0.5)
axis[0].set_title("PDF - Densidad de probabilidad")

# Graficar CDF (Función acumulada)
axis[1].plot(np.sort(data), np.sort(cdf), "b-", alpha=0.5)
axis[1].set_title("CDF - Función de distribución acumulada")

# Graficar PPF (Función cuantil)
axis[2].plot(np.sort(cdf), np.sort(ppf), "g-", alpha=0.5)
axis[2].set_title("PPF - Función cuantil inversa")

plt.tight_layout()
plt.show()
